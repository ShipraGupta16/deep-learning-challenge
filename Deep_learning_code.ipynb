# %% [markdown]
# ## Preprocessing

# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import pandas as pd
import tensorflow as tf

#  Import and read the charity_data.csv.
import pandas as pd
application_df = pd.read_csv("https://static.bc-edx.com/data/dl-1-2/m21/lms/starter/charity_data.csv")
application_df.head()
# Out:
#         EIN                                      NAME APPLICATION_TYPE  \
# 0  10520599              BLUE KNIGHTS MOTORCYCLE CLUB              T10
# 1  10531628    AMERICAN CHESAPEAKE CLUB CHARITABLE TR               T3
# 2  10547893        ST CLOUD PROFESSIONAL FIREFIGHTERS               T5
# 3  10553066            SOUTHSIDE ATHLETIC ASSOCIATION               T3
# 4  10556103  GENETIC RESEARCH INSTITUTE OF THE DESERT               T3
#
#         AFFILIATION CLASSIFICATION      USE_CASE  ORGANIZATION  STATUS  \
# 0       Independent          C1000    ProductDev   Association       1
# 1       Independent          C2000  Preservation  Co-operative       1
# 2  CompanySponsored          C3000    ProductDev   Association       1
# 3  CompanySponsored          C2000  Preservation         Trust       1
# 4       Independent          C1000     Heathcare         Trust       1
#
#       INCOME_AMT SPECIAL_CONSIDERATIONS  ASK_AMT  IS_SUCCESSFUL
# 0              0                      N     5000              1
# 1         1-9999                      N   108590              1
# 2              0                      N     5000              0
# 3    10000-24999                      N     6692              1
# 4  100000-499999                      N   142590              1

# %%
# Determine the number of unique values in each column.
application_df.nunique()
# Out:
# EIN                       34299
# NAME                      19568
# APPLICATION_TYPE             17
# AFFILIATION                   6
# CLASSIFICATION               71
# USE_CASE                      5
# ORGANIZATION                  4
# STATUS                        2
# INCOME_AMT                    9
# SPECIAL_CONSIDERATIONS        2
# ASK_AMT                    8747
# IS_SUCCESSFUL                 2
# dtype: int64

# %%
# Look at APPLICATION_TYPE value counts for binning
application_type_count = application_df['APPLICATION_TYPE'].value_counts()
application_type_count
# Out:
# APPLICATION_TYPE
# T3     27037
# T4      1542
# T6      1216
# T5      1173
# T19     1065
# T8       737
# T7       725
# T10      528
# T9       156
# T13       66
# T12       27
# T2        16
# T25        3
# T14        3
# T29        2
# T15        2
# T17        1
# Name: count, dtype: int64

# %%
# Choose a cutoff value and create a list of application types to be replaced
# use the variable name `application_types_to_replace`
application_types_to_replace = list(application_type_count[application_type_count < 500].index)

# Replace in dataframe
for app in application_types_to_replace:
    application_df['APPLICATION_TYPE'] = application_df['APPLICATION_TYPE'].replace(app,"Other")

# Check to make sure binning was successful
application_df['APPLICATION_TYPE'].value_counts()
# Out:
# APPLICATION_TYPE
# T3       27037
# T4        1542
# T6        1216
# T5        1173
# T19       1065
# T8         737
# T7         725
# T10        528
# Other      276
# Name: count, dtype: int64

# %%
# Look at CLASSIFICATION value counts for binning
classification_counts = application_df['CLASSIFICATION'].value_counts()
classification_counts
# Out:
# CLASSIFICATION
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
#          ...
# C4120        1
# C8210        1
# C2561        1
# C4500        1
# C2150        1
# Name: count, Length: 71, dtype: int64

# %%
# You may find it helpful to look at CLASSIFICATION value counts >1
classification_counts[classification_counts > 1]
# Out:
# CLASSIFICATION
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
# C7000      777
# C1700      287
# C4000      194
# C5000      116
# C1270      114
# C2700      104
# C2800       95
# C7100       75
# C1300       58
# C1280       50
# C1230       36
# C1400       34
# C7200       32
# C2300       32
# C1240       30
# C8000       20
# C7120       18
# C1500       16
# C1800       15
# C6000       15
# C1250       14
# C8200       11
# C1238       10
# C1278       10
# C1235        9
# C1237        9
# C7210        7
# C2400        6
# C1720        6
# C4100        6
# C1257        5
# C1600        5
# C1260        3
# C2710        3
# C0           3
# C3200        2
# C1234        2
# C1246        2
# C1267        2
# C1256        2
# Name: count, dtype: int64

# %%
# Choose a cutoff value and create a list of classifications to be replaced
# use the variable name `classifications_to_replace`
classifications_to_replace = list(classification_counts[classification_counts < 500].index)

# Replace in dataframe
for cls in classifications_to_replace:
    application_df['CLASSIFICATION'] = application_df['CLASSIFICATION'].replace(cls,"Other")

# Check to make sure binning was successful
application_df['CLASSIFICATION'].value_counts()
# Out:
# CLASSIFICATION
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
# Other     1484
# C7000      777
# Name: count, dtype: int64

# %%
# Convert categorical data to numeric with `pd.get_dummies`
numeric_application_df = pd.get_dummies(application_df)
numeric_application_df.head()
# Out:
#         EIN  STATUS  ASK_AMT  IS_SUCCESSFUL  \
# 0  10520599       1     5000              1
# 1  10531628       1   108590              1
# 2  10547893       1     5000              0
# 3  10553066       1     6692              1
# 4  10556103       1   142590              1
#
#    NAME_1 DAY RANCH RESCUE AND RURAL OKLAHOMA ANIMAL RESOURCE INC  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    NAME_100 BLACK MEN OF AMERICA  NAME_100 BLACK MEN OF MEMPHIS INC  \
# 0                          False                              False
# 1                          False                              False
# 2                          False                              False
# 3                          False                              False
# 4                          False                              False
#
#    NAME_100 BLACK MEN OF WEST GEORGIA INC  NAME_1150 WEBSTER STREET INC  \
# 0                                   False                         False
# 1                                   False                         False
# 2                                   False                         False
# 3                                   False                         False
# 4                                   False                         False
#
#    NAME_116TH CAVALRY REGIMENT CHAPTER OF THE US CAVALRY & ARMOR ASSOCIATION  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    ...  INCOME_AMT_1-9999  INCOME_AMT_10000-24999  INCOME_AMT_100000-499999  \
# 0  ...              False                   False                     False
# 1  ...               True                   False                     False
# 2  ...              False                   False                     False
# 3  ...              False                    True                     False
# 4  ...              False                   False                      True
#
#    INCOME_AMT_10M-50M  INCOME_AMT_1M-5M  INCOME_AMT_25000-99999  \
# 0               False             False                   False
# 1               False             False                   False
# 2               False             False                   False
# 3               False             False                   False
# 4               False             False                   False
#
#    INCOME_AMT_50M+  INCOME_AMT_5M-10M  SPECIAL_CONSIDERATIONS_N  \
# 0            False              False                      True
# 1            False              False                      True
# 2            False              False                      True
# 3            False              False                      True
# 4            False              False                      True
#
#    SPECIAL_CONSIDERATIONS_Y
# 0                     False
# 1                     False
# 2                     False
# 3                     False
# 4                     False
#
# [5 rows x 19614 columns]

# %%
# Split our preprocessed data into our features and target arrays
y = numeric_application_df["IS_SUCCESSFUL"]
X = numeric_application_df.drop(["IS_SUCCESSFUL"],axis=1)

# Split the preprocessed data into a training and testing dataset
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=50)

# %%
# Create a StandardScaler instances
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %% [markdown]
# ## Compile, Train and Evaluate the Model

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
nn = tf.keras.models.Sequential()

input_features = len(X_train_scaled[0])
hidden_nodes1=90
hidden_nodes2=30

# First hidden layer
nn.add(tf.keras.layers.Dense(units=hidden_nodes1, input_dim=input_features, activation='relu'))

# Second hidden layer
nn.add(tf.keras.layers.Dense(units=hidden_nodes2, activation='relu'))

# Output layer
nn.add(tf.keras.layers.Dense(units=1, activation='sigmoid'))

# Check the structure of the model
nn.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 90)                1765260
#
#  dense_1 (Dense)             (None, 30)                2730
#
#  dense_2 (Dense)             (None, 1)                 31
#
# =================================================================
# Total params: 1768021 (6.74 MB)
# Trainable params: 1768021 (6.74 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Compile the model
nn.compile(loss = 'binary_crossentropy', optimizer = 'adam', metrics=['accuracy'])

# %%
# Train the model
fit_model = nn.fit(X_train_scaled,y_train, epochs=100)
# Out:
# Epoch 1/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.4960 - accuracy: 0.7590
# Epoch 2/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.1259 - accuracy: 0.9538
# Epoch 3/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.0970 - accuracy: 0.9606
# Epoch 4/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.0934 - accuracy: 0.9617
# Epoch 5/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.0928 - accuracy: 0.9622
# Epoch 6/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.0919 - accuracy: 0.9626
# Epoch 7/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.0908 - accuracy: 0.9623
# Epoch 8/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.0902 - accuracy: 0.9623
# Epoch 9/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.0895 - accuracy: 0.9624
# Epoch 10/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.0893 - accuracy: 0.9633
# Epoch 11/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.0882 - accuracy: 0.9635
# Epoch 12/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.0878 - accuracy: 0.9635
# Epoch 13/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.0872 - accuracy: 0.9641
# Epoch 14/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.0866 - accuracy: 0.9636
# Epoch 15/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.0863 - accuracy: 0.9640
# Epoch 16/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.0854 - accuracy: 0.9647
# Epoch 17/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.0851 - accuracy: 0.9650
# Epoch 18/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.0848 - accuracy: 0.9650
# Epoch 19/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.0846 - accuracy: 0.9653
# Epoch 20/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.0838 - accuracy: 0.9657
# Epoch 21/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.0832 - accuracy: 0.9656
# Epoch 22/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.0838 - accuracy: 0.9656
# Epoch 23/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.0825 - accuracy: 0.9663
# Epoch 24/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.0822 - accuracy: 0.9661
# Epoch 25/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.0819 - accuracy: 0.9668
# Epoch 26/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.0818 - accuracy: 0.9658
# Epoch 27/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.0813 - accuracy: 0.9670
# Epoch 28/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.0809 - accuracy: 0.9670
# Epoch 29/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.0805 - accuracy: 0.9670
# Epoch 30/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.0801 - accuracy: 0.9668
# Epoch 31/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.0800 - accuracy: 0.9668
# Epoch 32/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.0797 - accuracy: 0.9678
# Epoch 33/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.0788 - accuracy: 0.9672
# Epoch 34/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.0786 - accuracy: 0.9675
# Epoch 35/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.0786 - accuracy: 0.9677
# Epoch 36/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.0780 - accuracy: 0.9678
# Epoch 37/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.0777 - accuracy: 0.9683
# Epoch 38/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.0771 - accuracy: 0.9686
# Epoch 39/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.0770 - accuracy: 0.9684
# Epoch 40/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.0767 - accuracy: 0.9685
# Epoch 41/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.0765 - accuracy: 0.9681
# Epoch 42/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.0761 - accuracy: 0.9686
# Epoch 43/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.0762 - accuracy: 0.9683
# Epoch 44/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.0754 - accuracy: 0.9694
# Epoch 45/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.0752 - accuracy: 0.9691
# Epoch 46/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.0752 - accuracy: 0.9694
# Epoch 47/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.0747 - accuracy: 0.9689
# Epoch 48/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.0748 - accuracy: 0.9693
# Epoch 49/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.0745 - accuracy: 0.9698
# Epoch 50/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.0740 - accuracy: 0.9694
# Epoch 51/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.0738 - accuracy: 0.9694
# Epoch 52/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.0737 - accuracy: 0.9696
# Epoch 53/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.0736 - accuracy: 0.9701
# Epoch 54/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.0734 - accuracy: 0.9700
# Epoch 55/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.0727 - accuracy: 0.9705
# Epoch 56/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.0732 - accuracy: 0.9700
# Epoch 57/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.0728 - accuracy: 0.9701
# Epoch 58/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.0729 - accuracy: 0.9700
# Epoch 59/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.0724 - accuracy: 0.9700
# Epoch 60/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.0724 - accuracy: 0.9704
# Epoch 61/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.0720 - accuracy: 0.9706
# Epoch 62/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.0714 - accuracy: 0.9706
# Epoch 63/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.0715 - accuracy: 0.9708
# Epoch 64/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.0714 - accuracy: 0.9704
# Epoch 65/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.0714 - accuracy: 0.9707
# Epoch 66/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.0710 - accuracy: 0.9709
# Epoch 67/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.0707 - accuracy: 0.9708
# Epoch 68/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.0709 - accuracy: 0.9703
# Epoch 69/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.0709 - accuracy: 0.9713
# Epoch 70/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.0727 - accuracy: 0.9710
# Epoch 71/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.0705 - accuracy: 0.9708
# Epoch 72/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.0698 - accuracy: 0.9715
# Epoch 73/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.0706 - accuracy: 0.9709
# Epoch 74/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.0700 - accuracy: 0.9713
# Epoch 75/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.0703 - accuracy: 0.9710
# Epoch 76/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.0698 - accuracy: 0.9713
# Epoch 77/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.0699 - accuracy: 0.9713
# Epoch 78/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.0696 - accuracy: 0.9716
# Epoch 79/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.0695 - accuracy: 0.9714
# Epoch 80/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.0697 - accuracy: 0.9711
# Epoch 81/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.0697 - accuracy: 0.9708
# Epoch 82/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.0692 - accuracy: 0.9714
# Epoch 83/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.0695 - accuracy: 0.9712
# Epoch 84/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.0689 - accuracy: 0.9714
# Epoch 85/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.0693 - accuracy: 0.9712
# Epoch 86/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.0687 - accuracy: 0.9717
# Epoch 87/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.0686 - accuracy: 0.9719
# Epoch 88/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.0693 - accuracy: 0.9711
# Epoch 89/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.0686 - accuracy: 0.9715
# Epoch 90/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.0690 - accuracy: 0.9713
# Epoch 91/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.0683 - accuracy: 0.9717
# Epoch 92/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.0682 - accuracy: 0.9719
# Epoch 93/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.0683 - accuracy: 0.9713
# Epoch 94/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.0684 - accuracy: 0.9717
# Epoch 95/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.0675 - accuracy: 0.9717
# Epoch 96/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.0682 - accuracy: 0.9719
# Epoch 97/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.0680 - accuracy: 0.9717
# Epoch 98/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.0678 - accuracy: 0.9721
# Epoch 99/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.0678 - accuracy: 0.9716
# Epoch 100/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.0679 - accuracy: 0.9719

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 268/268 - 0s - loss: 1.0489 - accuracy: 0.6779 - 326ms/epoch - 1ms/step
# Loss: 1.0488862991333008, Accuracy: 0.6779008507728577

# %% [markdown]
# Second attempt

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
nn = tf.keras.models.Sequential()

input_features = len(X_train_scaled[0])
hidden_nodes1=100
hidden_nodes2=35
hidden_nodes3=25

# First hidden layer
nn.add(tf.keras.layers.Dense(units=hidden_nodes1, input_dim=input_features, activation='relu'))

# Second hidden layer
nn.add(tf.keras.layers.Dense(units=hidden_nodes2, activation='relu'))

# Third hidden layer
nn.add(tf.keras.layers.Dense(units=hidden_nodes3, activation='tanh'))

# Output layer
nn.add(tf.keras.layers.Dense(units=1, activation='sigmoid'))

# Check the structure of the model
nn.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_3 (Dense)             (None, 100)               1961400
#
#  dense_4 (Dense)             (None, 35)                3535
#
#  dense_5 (Dense)             (None, 25)                900
#
#  dense_6 (Dense)             (None, 1)                 26
#
# =================================================================
# Total params: 1965861 (7.50 MB)
# Trainable params: 1965861 (7.50 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# compile the model
nn.compile(loss = 'binary_crossentropy', optimizer = 'adam', metrics=['accuracy'])

# %%
# Train the model
fit_model = nn.fit(X_train_scaled,y_train, epochs=100)
# Out:
# Epoch 1/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.4736 - accuracy: 0.7763
# Epoch 2/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.1430 - accuracy: 0.9507
# Epoch 3/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.1010 - accuracy: 0.9616
# Epoch 4/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.0937 - accuracy: 0.9622
# Epoch 5/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.0910 - accuracy: 0.9626
# Epoch 6/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.0905 - accuracy: 0.9626
# Epoch 7/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.0901 - accuracy: 0.9626
# Epoch 8/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.0890 - accuracy: 0.9633
# Epoch 9/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.0886 - accuracy: 0.9631
# Epoch 10/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.0885 - accuracy: 0.9632
# Epoch 11/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.0888 - accuracy: 0.9626
# Epoch 12/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.0878 - accuracy: 0.9634
# Epoch 13/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.0876 - accuracy: 0.9640
# Epoch 14/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.0871 - accuracy: 0.9641
# Epoch 15/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.0888 - accuracy: 0.9635
# Epoch 16/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.0881 - accuracy: 0.9640
# Epoch 17/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.0874 - accuracy: 0.9638
# Epoch 18/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.0887 - accuracy: 0.9607
# Epoch 19/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.0876 - accuracy: 0.9633
# Epoch 20/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.0871 - accuracy: 0.9644
# Epoch 21/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.0868 - accuracy: 0.9639
# Epoch 22/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.0864 - accuracy: 0.9639
# Epoch 23/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.0859 - accuracy: 0.9641
# Epoch 24/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.0857 - accuracy: 0.9642
# Epoch 25/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.0854 - accuracy: 0.9643
# Epoch 26/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.0850 - accuracy: 0.9645
# Epoch 27/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.0842 - accuracy: 0.9645
# Epoch 28/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.0845 - accuracy: 0.9652
# Epoch 29/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.0841 - accuracy: 0.9648
# Epoch 30/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.0839 - accuracy: 0.9649
# Epoch 31/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.0833 - accuracy: 0.9656
# Epoch 32/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.0847 - accuracy: 0.9652
# Epoch 33/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.0834 - accuracy: 0.9656
# Epoch 34/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.0845 - accuracy: 0.9647
# Epoch 35/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.0834 - accuracy: 0.9646
# Epoch 36/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.0841 - accuracy: 0.9645
# Epoch 37/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.0848 - accuracy: 0.9645
# Epoch 38/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.0856 - accuracy: 0.9644
# Epoch 39/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.0839 - accuracy: 0.9654
# Epoch 40/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.0834 - accuracy: 0.9647
# Epoch 41/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.0838 - accuracy: 0.9654
# Epoch 42/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.0828 - accuracy: 0.9651
# Epoch 43/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.0831 - accuracy: 0.9662
# Epoch 44/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.0834 - accuracy: 0.9658
# Epoch 45/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.0837 - accuracy: 0.9656
# Epoch 46/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.0844 - accuracy: 0.9654
# Epoch 47/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.0844 - accuracy: 0.9651
# Epoch 48/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.0833 - accuracy: 0.9662
# Epoch 49/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.0834 - accuracy: 0.9652
# Epoch 50/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.0829 - accuracy: 0.9660
# Epoch 51/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.0826 - accuracy: 0.9663
# Epoch 52/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.0825 - accuracy: 0.9654
# Epoch 53/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.0825 - accuracy: 0.9658
# Epoch 54/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.0824 - accuracy: 0.9661
# Epoch 55/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.0820 - accuracy: 0.9666
# Epoch 56/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.0819 - accuracy: 0.9661
# Epoch 57/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.0827 - accuracy: 0.9659
# Epoch 58/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.0823 - accuracy: 0.9665
# Epoch 59/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.0816 - accuracy: 0.9667
# Epoch 60/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.0817 - accuracy: 0.9666
# Epoch 61/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.0813 - accuracy: 0.9661
# Epoch 62/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.0833 - accuracy: 0.9661
# Epoch 63/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.0833 - accuracy: 0.9662
# Epoch 64/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.0825 - accuracy: 0.9666
# Epoch 65/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.0831 - accuracy: 0.9660
# Epoch 66/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.0813 - accuracy: 0.9670
# Epoch 67/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.0809 - accuracy: 0.9672
# Epoch 68/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.0825 - accuracy: 0.9659
# Epoch 69/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.0826 - accuracy: 0.9664
# Epoch 70/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.0829 - accuracy: 0.9659
# Epoch 71/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.0820 - accuracy: 0.9668
# Epoch 72/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.0817 - accuracy: 0.9663
# Epoch 73/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.0820 - accuracy: 0.9668
# Epoch 74/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.0817 - accuracy: 0.9668
# Epoch 75/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.0815 - accuracy: 0.9665
# Epoch 76/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.0817 - accuracy: 0.9667
# Epoch 77/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.0815 - accuracy: 0.9667
# Epoch 78/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.0807 - accuracy: 0.9671
# Epoch 79/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.0809 - accuracy: 0.9671
# Epoch 80/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.0809 - accuracy: 0.9672
# Epoch 81/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.0817 - accuracy: 0.9667
# Epoch 82/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.0802 - accuracy: 0.9670
# Epoch 83/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.0799 - accuracy: 0.9672
# Epoch 84/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.0803 - accuracy: 0.9672
# Epoch 85/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.0805 - accuracy: 0.9672
# Epoch 86/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.0800 - accuracy: 0.9678
# Epoch 87/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.0806 - accuracy: 0.9669
# Epoch 88/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.0796 - accuracy: 0.9670
# Epoch 89/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.0805 - accuracy: 0.9673
# Epoch 90/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.0796 - accuracy: 0.9663
# Epoch 91/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.0798 - accuracy: 0.9673
# Epoch 92/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.0800 - accuracy: 0.9668
# Epoch 93/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.0791 - accuracy: 0.9676
# Epoch 94/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.0796 - accuracy: 0.9678
# Epoch 95/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.0803 - accuracy: 0.9677
# Epoch 96/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.0810 - accuracy: 0.9675
# Epoch 97/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.0808 - accuracy: 0.9670
# Epoch 98/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.0806 - accuracy: 0.9675
# Epoch 99/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.0797 - accuracy: 0.9682
# Epoch 100/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.0789 - accuracy: 0.9680

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 268/268 - 0s - loss: 0.5491 - accuracy: 0.6028 - 311ms/epoch - 1ms/step
# Loss: 0.5491129755973816, Accuracy: 0.6027988195419312

# %% [markdown]
# Third attempt

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
nn = tf.keras.models.Sequential()

input_features = len(X_train_scaled[0])
hidden_nodes1=100
hidden_nodes2=50
hidden_nodes3=30

# First hidden layer
nn.add(tf.keras.layers.Dense(units=hidden_nodes1, input_dim=input_features, activation='relu'))

# Second hidden layer
nn.add(tf.keras.layers.Dense(units=hidden_nodes2, activation='relu'))

# Third hidden layer
nn.add(tf.keras.layers.Dense(units=hidden_nodes3, activation='tanh'))

# Output layer
nn.add(tf.keras.layers.Dense(units=1, activation='sigmoid'))

# Check the structure of the model
nn.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_7 (Dense)             (None, 100)               1961400
#
#  dense_8 (Dense)             (None, 50)                5050
#
#  dense_9 (Dense)             (None, 30)                1530
#
#  dense_10 (Dense)            (None, 1)                 31
#
# =================================================================
# Total params: 1968011 (7.51 MB)
# Trainable params: 1968011 (7.51 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Compile the model
nn.compile(loss = 'binary_crossentropy', optimizer = 'adam', metrics=['accuracy'])

# %%
# Train the model
fit_model = nn.fit(X_train_scaled,y_train, epochs=100)
# Out:
# Epoch 1/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.4733 - accuracy: 0.7767
# Epoch 2/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.1322 - accuracy: 0.9535
# Epoch 3/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.0995 - accuracy: 0.9617
# Epoch 4/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.0941 - accuracy: 0.9621
# Epoch 5/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.0923 - accuracy: 0.9622
# Epoch 6/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.0907 - accuracy: 0.9623
# Epoch 7/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.0901 - accuracy: 0.9623
# Epoch 8/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.0895 - accuracy: 0.9629
# Epoch 9/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.0885 - accuracy: 0.9629
# Epoch 10/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.0881 - accuracy: 0.9638
# Epoch 11/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.0878 - accuracy: 0.9637
# Epoch 12/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.0872 - accuracy: 0.9637
# Epoch 13/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.0866 - accuracy: 0.9638
# Epoch 14/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.0861 - accuracy: 0.9645
# Epoch 15/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.0857 - accuracy: 0.9647
# Epoch 16/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.0860 - accuracy: 0.9647
# Epoch 17/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.0854 - accuracy: 0.9643
# Epoch 18/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.0860 - accuracy: 0.9645
# Epoch 19/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.0850 - accuracy: 0.9646
# Epoch 20/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.0850 - accuracy: 0.9650
# Epoch 21/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.0844 - accuracy: 0.9652
# Epoch 22/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.0850 - accuracy: 0.9650
# Epoch 23/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.0846 - accuracy: 0.9652
# Epoch 24/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.0839 - accuracy: 0.9655
# Epoch 25/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.0834 - accuracy: 0.9653
# Epoch 26/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.0839 - accuracy: 0.9651
# Epoch 27/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.0845 - accuracy: 0.9656
# Epoch 28/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.0836 - accuracy: 0.9653
# Epoch 29/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.0837 - accuracy: 0.9651
# Epoch 30/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.0847 - accuracy: 0.9647
# Epoch 31/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.0848 - accuracy: 0.9651
# Epoch 32/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.0831 - accuracy: 0.9649
# Epoch 33/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.0841 - accuracy: 0.9652
# Epoch 34/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.0832 - accuracy: 0.9661
# Epoch 35/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.0839 - accuracy: 0.9656
# Epoch 36/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.0843 - accuracy: 0.9657
# Epoch 37/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.0832 - accuracy: 0.9658
# Epoch 38/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.0822 - accuracy: 0.9655
# Epoch 39/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.0831 - accuracy: 0.9661
# Epoch 40/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.0829 - accuracy: 0.9658
# Epoch 41/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.0830 - accuracy: 0.9659
# Epoch 42/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.0833 - accuracy: 0.9661
# Epoch 43/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.0833 - accuracy: 0.9665
# Epoch 44/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.0821 - accuracy: 0.9665
# Epoch 45/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.0834 - accuracy: 0.9665
# Epoch 46/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.0827 - accuracy: 0.9672
# Epoch 47/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.0823 - accuracy: 0.9665
# Epoch 48/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.0852 - accuracy: 0.9652
# Epoch 49/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.0830 - accuracy: 0.9661
# Epoch 50/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.0824 - accuracy: 0.9671
# Epoch 51/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.0824 - accuracy: 0.9668
# Epoch 52/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.0819 - accuracy: 0.9665
# Epoch 53/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.0821 - accuracy: 0.9666
# Epoch 54/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.0820 - accuracy: 0.9655
# Epoch 55/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.0823 - accuracy: 0.9668
# Epoch 56/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.0816 - accuracy: 0.9672
# Epoch 57/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.0820 - accuracy: 0.9665
# Epoch 58/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.0825 - accuracy: 0.9666
# Epoch 59/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.0816 - accuracy: 0.9666
# Epoch 60/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.0816 - accuracy: 0.9665
# Epoch 61/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.0819 - accuracy: 0.9666
# Epoch 62/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.0811 - accuracy: 0.9670
# Epoch 63/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.0814 - accuracy: 0.9670
# Epoch 64/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.0821 - accuracy: 0.9664
# Epoch 65/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.0814 - accuracy: 0.9663
# Epoch 66/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.0814 - accuracy: 0.9670
# Epoch 67/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.0819 - accuracy: 0.9664
# Epoch 68/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.0818 - accuracy: 0.9668
# Epoch 69/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.0818 - accuracy: 0.9668
# Epoch 70/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.0813 - accuracy: 0.9670
# Epoch 71/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.0815 - accuracy: 0.9673
# Epoch 72/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.0813 - accuracy: 0.9670
# Epoch 73/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.0809 - accuracy: 0.9673
# Epoch 74/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.0800 - accuracy: 0.9674
# Epoch 75/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.0805 - accuracy: 0.9678
# Epoch 76/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.0810 - accuracy: 0.9671
# Epoch 77/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.0807 - accuracy: 0.9673
# Epoch 78/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.0808 - accuracy: 0.9675
# Epoch 79/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.0813 - accuracy: 0.9674
# Epoch 80/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.0814 - accuracy: 0.9675
# Epoch 81/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.0806 - accuracy: 0.9672
# Epoch 82/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.0810 - accuracy: 0.9675
# Epoch 83/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.0808 - accuracy: 0.9674
# Epoch 84/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.0821 - accuracy: 0.9666
# Epoch 85/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.0816 - accuracy: 0.9667
# Epoch 86/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.0809 - accuracy: 0.9675
# Epoch 87/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.0807 - accuracy: 0.9674
# Epoch 88/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.0807 - accuracy: 0.9677
# Epoch 89/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.0806 - accuracy: 0.9678
# Epoch 90/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.0799 - accuracy: 0.9684
# Epoch 91/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.0798 - accuracy: 0.9683
# Epoch 92/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.0820 - accuracy: 0.9668
# Epoch 93/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.0828 - accuracy: 0.9666
# Epoch 94/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.0817 - accuracy: 0.9669
# Epoch 95/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.0810 - accuracy: 0.9679
# Epoch 96/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.0814 - accuracy: 0.9675
# Epoch 97/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.0817 - accuracy: 0.9673
# Epoch 98/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.0812 - accuracy: 0.9675
# Epoch 99/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.0830 - accuracy: 0.9666
# Epoch 100/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.0822 - accuracy: 0.9667

# %%
# Evaluate best model against full test data
best_model = tuner.get_best_models(1)[0]
model_loss, model_accuracy = best_model.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 268/268 - 0s - loss: 0.6422 - accuracy: 0.8078 - 235ms/epoch - 876us/step
# Loss: 0.6421944499015808, Accuracy: 0.8078134059906006

# %%
# Export our model to HDF5 file
nn.save('..AlphabetSoupCharity.h5/')
# Out:
# INFO:tensorflow:Assets written to: ..AlphabetSoupCharity.h5/assets
# INFO:tensorflow:Assets written to: ..AlphabetSoupCharity.h5/assets
